# %% [markdown]
# # HDSC stage B tag along code
# # Apurv Deshpande

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#after importing the libraries, we get the dataset.

# %%
df=pd.read_csv("energydata_complete.csv")
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         19735 non-null  object
#  1   Appliances   19735 non-null  int64
#  2   lights       19735 non-null  int64
#  3   T1           19735 non-null  float64
#  4   RH_1         19735 non-null  float64
#  5   T2           19735 non-null  float64
#  6   RH_2         19735 non-null  float64
#  7   T3           19735 non-null  float64
#  8   RH_3         19735 non-null  float64
#  9   T4           19735 non-null  float64
#  10  RH_4         19735 non-null  float64
#  11  T5           19735 non-null  float64
#  12  RH_5         19735 non-null  float64
#  13  T6           19735 non-null  float64
#  14  RH_6         19735 non-null  float64
#  15  T7           19735 non-null  float64
#  16  RH_7         19735 non-null  float64
#  17  T8           19735 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
df.describe().T
# Out:
#                count        mean         std         min         25%  \
# Appliances   19735.0   97.694958  102.524891   10.000000   50.000000
# lights       19735.0    3.801875    7.935988    0.000000    0.000000
# T1           19735.0   21.686571    1.606066   16.790000   20.760000
# RH_1         19735.0   40.259739    3.979299   27.023333   37.333333
# T2           19735.0   20.341219    2.192974   16.100000   18.790000
# RH_2         19735.0   40.420420    4.069813   20.463333   37.900000
# T3           19735.0   22.267611    2.006111   17.200000   20.790000
# RH_3         19735.0   39.242500    3.254576   28.766667   36.900000
# T4           19735.0   20.855335    2.042884   15.100000   19.530000
# RH_4         19735.0   39.026904    4.341321   27.660000   35.530000
# T5           19735.0   19.592106    1.844623   15.330000   18.277500
# RH_5         19735.0   50.949283    9.022034   29.815000   45.400000
# T6           19735.0    7.910939    6.090347   -6.065000    3.626667
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df.corr().T
# Out:
#              Appliances    lights        T1      RH_1        T2      RH_2  \
# Appliances     1.000000  0.197278  0.055447  0.086031  0.120073 -0.060465
# lights         0.197278  1.000000 -0.023528  0.106968 -0.005622  0.050985
# T1             0.055447 -0.023528  1.000000  0.164006  0.836834 -0.002509
# RH_1           0.086031  0.106968  0.164006  1.000000  0.269839  0.797535
# T2             0.120073 -0.005622  0.836834  0.269839  1.000000 -0.165610
# RH_2          -0.060465  0.050985 -0.002509  0.797535 -0.165610  1.000000
# T3             0.085060 -0.097393  0.892402  0.253230  0.735245  0.137319
# RH_3           0.036292  0.131161 -0.028550  0.844677  0.121497  0.678326
# T4             0.040281 -0.008859  0.877001  0.106180  0.762066 -0.047304
# RH_4           0.016965  0.114936  0.097861  0.880359  0.231563  0.721435
# T5             0.019760 -0.078745  0.885247  0.205797  0.720550  0.110409
# RH_5           0.006955  0.141233 -0.014782  0.303258  0.029595  0.250271
# ...

# %%
df.isna().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(18,10))
sns.heatmap(df.corr() )
plt.show()

# %%
model = LinearRegression(fit_intercept=True)

# %%
model.fit(df['T2'].values.reshape(-1,1), df['T6'].values.reshape(-1,1))
# Out:
# LinearRegression()

# %%
xmin = [[df['T2'].min()],[df['T2'].max()]]
ymin = model.predict(xmin)

# %%
ymin
# Out:
# array([[-1.52603433],
#        [29.08339347]])

# %%
preds = model.predict(df['T2'].values.reshape(-1,1))
print("THE MEAN SCQUARED ERROR IS: ")
np.sqrt((mean_squared_error(df['T6'].values.reshape(-1,1), preds)))
# Out:
# THE MEAN SCQUARED ERROR IS:
# 3.6444644873484573

# %%
plt.plot(xmin, ymin, c='blue')
plt.xlabel("T2 -> LIVING ROOM")
plt.ylabel("T6 -> Outside North")
plt.show()

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %% [markdown]
# # multiple regression

# %%
newdf = df.drop(['date', 'lights'], axis=1)
newdf.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %% [markdown]
# # mimaxscaler:

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
otherdf = pd.DataFrame(scaler.fit_transform(newdf), columns=newdf.columns)
df2 = otherdf.drop(columns=['Appliances'])
temp = otherdf['Appliances']

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df2, temp,
test_size=0.3, random_state=42)

# %% [markdown]
# ## fitting the model to training set:

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred = linear_model.predict(x_test)

# %%
linear_model.score(x_train, y_train)  #training score
# Out:
# 0.14471942308518737

# %%
linear_model.score(x_test, y_test)  #testing score
# Out:
# 0.14890246319303535

# %% [markdown]
# # questions 13,14,15: related to metrics

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_test, pred))
# Out:
# 0.05013362397742955

# %%
print(np.sum(np.square(y_test - pred)))
# Out:
# 45.34762967266377

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 0.0875144494766171

# %%
from sklearn.metrics import r2_score
print("R^2 Score:",r2_score(y_test, pred))
# Out:
# R^2 Score: 0.14890246319303535

# %% [markdown]
# # RIDGE

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=0.4)
ridge.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4)

# %%
newpred = ridge.predict(x_test)

# %%
newpred
# Out:
# array([0.03321872, 0.24043824, 0.03461337, ..., 0.06872351, 0.10025536,
#        0.05851175])

# %%
np.sqrt(mean_squared_error(y_test, newpred))
# Out:
# 0.08753385704628003

# %% [markdown]
# # this, using linear and ridge regression the mean squared error value is approximately same.

# %% [markdown]
# # LASSO

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.001)
lasso.fit(x_train, y_train)

finalpred = lasso.predict(x_test)

from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test, finalpred))
# Out:
# 0.09358170467245137

# %% [markdown]
# # ---------------THANK YOU------------------
